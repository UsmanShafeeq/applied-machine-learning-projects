# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 1. Title & Introduction

# %% [markdown]
# #  Top 1000 GitHub Repositories Analysis
#
# ##  Introduction
# What makes a GitHub repository successful?
# In this project, we analyze the **Top 1000 GitHub repositories** to uncover patterns behind popularity, engagement, and programming trends.
#
# ---
#
# ##  Objectives
# - Analyze stars and forks
# - Identify top programming languages
# - Understand what makes repositories popular
# - Extract actionable insights
#
# ---
#
# 💡 If you find this useful, please upvote 👍

# %% [markdown]
# # 2 Import Libraries

# %%
# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px

# Settings for better visualization
sns.set(style="whitegrid")
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# # 3 Load the Dataset

# %%
# Import libraries
import pandas as pd
from IPython.display import display  # For Jupyter notebook display

# File path
file_path = "../datasets/github_top_repositories.csv"

# Read CSV with error handling and display first rows
try:
    df = pd.read_csv(file_path)
    print("CSV loaded successfully!")
    display(df.head())  # Shows first 5 rows in Jupyter
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except pd.errors.EmptyDataError:
    print("Error: File is empty")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# CSV loaded successfully!
#              Domain    Repository Name                 Full Name  \
# 0  Machine Learning         tensorflow     tensorflow/tensorflow
# 1  Machine Learning       transformers  huggingface/transformers
# 2  Machine Learning       prompts.chat            f/prompts.chat
# 3  Machine Learning            pytorch           pytorch/pytorch
# 4  Machine Learning  LLMs-from-scratch   rasbt/LLMs-from-scratch
#
#                                          Description  Primary Language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  f.k.a. Awesome ChatGPT Prompts. Share, discove...              HTML
# 3  Tensors and Dynamic neural networks in Python ...            Python
# 4  Implement a ChatGPT-like LLM in PyTorch from s...  Jupyter Notebook
#
#    Stars Count  Forks Count  Watchers Count  Open Issues Count  Has Wiki  \
# 0       194126        75247          194126               3715     False
# 1       157772        32464          157772               2282      True
# 2       152186        19999          152186                 28      True
# 3        98216        27194           98216              18055      True
# 4        87955        13422           87955                  1     False
#
#    Has Pages  Has Projects  Size (KB)            Created At  \
# 0      False          True    1288956  2015-11-07T01:19:20Z
# 1      False          True     453964  2018-10-29T13:56:00Z
# 2       True          True     231182  2022-12-05T13:54:13Z
# 3      False          True    1273608  2016-08-13T05:26:41Z
# 4      False         False      15703  2023-07-23T18:15:57Z
#
#              Updated At             Pushed At Default Branch  Owner Login  \
# 0  2026-03-14T00:28:29Z  2026-03-14T01:48:00Z         master   tensorflow
# 1  2026-03-14T01:38:18Z  2026-03-13T23:15:04Z           main  huggingface
# 2  2026-03-14T02:08:32Z  2026-03-13T14:06:54Z           main            f
# 3  2026-03-14T01:40:49Z  2026-03-14T02:08:49Z           main      pytorch
# 4  2026-03-14T02:06:45Z  2026-03-07T23:05:50Z           main        rasbt
#
#      Owner Type                               License  \
# 0  Organization                    Apache License 2.0
# 1  Organization                    Apache License 2.0
# 2          User  Creative Commons Zero v1.0 Universal
# 3  Organization                                 Other
# 4          User                                 Other
#
#                                               Topics
# 0  deep-learning, deep-neural-networks, distribut...
# 1  audio, deep-learning, deepseek, gemma, glm, ha...
# 2  ai, artificial-intelligence, awesome-list, cha...
# 3  autograd, deep-learning, gpu, machine-learning...
# 4  ai, artificial-intelligence, chatbot, chatgpt,...

# %% [markdown]
# # 3️ Explore the Dataset

# %%
# Show the first 5 rows
df.head()
# Out:
#              Domain    Repository Name                 Full Name  \
# 0  Machine Learning         tensorflow     tensorflow/tensorflow
# 1  Machine Learning       transformers  huggingface/transformers
# 2  Machine Learning       prompts.chat            f/prompts.chat
# 3  Machine Learning            pytorch           pytorch/pytorch
# 4  Machine Learning  LLMs-from-scratch   rasbt/LLMs-from-scratch
#
#                                          Description  Primary Language  \
# 0  An Open Source Machine Learning Framework for ...               C++
# 1  🤗 Transformers: the model-definition framework...            Python
# 2  f.k.a. Awesome ChatGPT Prompts. Share, discove...              HTML
# 3  Tensors and Dynamic neural networks in Python ...            Python
# 4  Implement a ChatGPT-like LLM in PyTorch from s...  Jupyter Notebook
#
#    Stars Count  Forks Count  Watchers Count  Open Issues Count  Has Wiki  \
# 0       194126        75247          194126               3715     False
# 1       157772        32464          157772               2282      True
# 2       152186        19999          152186                 28      True
# 3        98216        27194           98216              18055      True
# 4        87955        13422           87955                  1     False
#
#    Has Pages  Has Projects  Size (KB)            Created At  \
# 0      False          True    1288956  2015-11-07T01:19:20Z
# 1      False          True     453964  2018-10-29T13:56:00Z
# 2       True          True     231182  2022-12-05T13:54:13Z
# 3      False          True    1273608  2016-08-13T05:26:41Z
# 4      False         False      15703  2023-07-23T18:15:57Z
#
#              Updated At             Pushed At Default Branch  Owner Login  \
# 0  2026-03-14T00:28:29Z  2026-03-14T01:48:00Z         master   tensorflow
# 1  2026-03-14T01:38:18Z  2026-03-13T23:15:04Z           main  huggingface
# 2  2026-03-14T02:08:32Z  2026-03-13T14:06:54Z           main            f
# 3  2026-03-14T01:40:49Z  2026-03-14T02:08:49Z           main      pytorch
# 4  2026-03-14T02:06:45Z  2026-03-07T23:05:50Z           main        rasbt
#
#      Owner Type                               License  \
# 0  Organization                    Apache License 2.0
# 1  Organization                    Apache License 2.0
# 2          User  Creative Commons Zero v1.0 Universal
# 3  Organization                                 Other
# 4          User                                 Other
#
#                                               Topics
# 0  deep-learning, deep-neural-networks, distribut...
# 1  audio, deep-learning, deepseek, gemma, glm, ha...
# 2  ai, artificial-intelligence, awesome-list, cha...
# 3  autograd, deep-learning, gpu, machine-learning...
# 4  ai, artificial-intelligence, chatbot, chatgpt,...

# %%
# Last five row 
df.tail()
# Out:
#       Domain Repository Name                 Full Name  \
# 2995  DevOps        websoft9         Websoft9/websoft9
# 2996  DevOps        nodepass  NodePassProject/nodepass
# 2997  DevOps        loonflow       blackholll/loonflow
# 2998  DevOps      terraboard     camptocamp/terraboard
# 2999  DevOps           runme            runmedev/runme
#
#                                             Description Primary Language  \
# 2995  Applications self-hosting and DevOps platform ...           Python
# 2996  A secure, efficient TCP/UDP tunneling solution...               Go
# 2997  A Intelligent and Visual Process Automation Sy...       TypeScript
# 2998  :earth_africa: :clipboard:  A web dashboard to...               Go
# 2999               DevOps Notebooks Built with Markdown               Go
#
#       Stars Count  Forks Count  Watchers Count  Open Issues Count  Has Wiki  \
# 2995         2086          318            2086                 56      True
# 2996         2082          229            2082                  0     False
# 2997         2047          705            2047                 13      True
# 2998         2002          167            2002                 13      True
# 2999         2000           84            2000                149      True
#
#       Has Pages  Has Projects  Size (KB)            Created At  \
# 2995       True          True      70233  2020-12-18T01:29:26Z
# 2996      False         False       2566  2024-12-19T08:26:03Z
# 2997      False          True      65660  2018-02-08T06:26:53Z
# 2998       True          True      11638  2017-07-19T08:31:38Z
# 2999      False          True     101987  2022-07-18T07:58:54Z
#
#                 Updated At             Pushed At Default Branch  \
# 2995  2026-03-10T10:47:47Z  2026-02-12T01:16:49Z           main
# 2996  2026-03-13T17:57:47Z  2026-03-09T15:21:00Z           main
# 2997  2026-03-04T11:37:44Z  2026-03-14T00:52:09Z         master
# 2998  2026-03-11T12:51:22Z  2026-03-08T03:33:57Z         master
# 2999  2026-03-11T05:42:03Z  2026-03-13T17:34:30Z           main
#
#           Owner Login    Owner Type                                  License  \
# 2995         Websoft9  Organization                                    Other
# 2996  NodePassProject  Organization  BSD 3-Clause "New" or "Revised" License
# 2997       blackholll          User   GNU Affero General Public License v3.0
# 2998       camptocamp  Organization                       Apache License 2.0
# 2999         runmedev  Organization                       Apache License 2.0
#
#                                                  Topics
# 2995  appstore, cicd, cloud-native, cockpit-project,...
# 2996  api-rest, connection-pooling, cybersecurity, d...
# 2997  devops, django, python, ticket, workflow, work...
# 2998  aws, devops, devops-tools, diff, go, infrastru...
# 2999      cloud, devops, markdown, notebooks, workflows

# %%
# Random 5 rows
df.sample(5)
# Out:
#                Domain          Repository Name  \
# 2495       Blockchain  awesome-blockchain-rust
# 1534             Rust                 carbonyl
# 1981  Web Development                  Pi-Temp
# 392     Deep Learning                 ai-guide
# 2879           DevOps                oneuptime
#
#                                        Full Name  \
# 2495  rust-in-blockchain/awesome-blockchain-rust
# 1534                             fathyb/carbonyl
# 1981                               cwalk/Pi-Temp
# 392                              liyupi/ai-guide
# 2879                         OneUptime/oneuptime
#
#                                             Description Primary Language  \
# 2495  Collect libraries and packages about blockchai...              NaN
# 1534              Chromium running inside your terminal             Rust
# 1981  Web server using a Raspberry Pi and DHT22 sens...       JavaScript
# 392   程序员鱼皮的 AI 资源大全 + Vibe Coding 零基础教程，分享大模型选择指南（D...       JavaScript
# 2879  Complete open-source monitoring and observabil...       TypeScript
#
#       Stars Count  Forks Count  Watchers Count  Open Issues Count  Has Wiki  \
# 2495         2769          296            2769                  9      True
# 1534        15960          331           15960                 79      True
# 1981          135           67             135                  0      True
# 392          9608         1026            9608                  0     False
# 2879         6606          332            6606                192      True
#
#       Has Pages  Has Projects  Size (KB)            Created At  \
# 2495      False          True        133  2019-05-05T01:21:11Z
# 1534      False          True        283  2023-01-20T10:58:22Z
# 1981      False          True        268  2016-03-24T17:15:11Z
# 392       False          True       3521  2025-02-13T05:47:46Z
# 2879      False          True     525769  2021-06-27T13:19:42Z
#
#                 Updated At             Pushed At Default Branch  \
# 2495  2026-03-13T13:41:26Z  2025-12-19T19:59:10Z         master
# 1534  2026-03-14T02:00:33Z  2024-07-01T14:31:50Z           main
# 1981  2025-09-19T00:30:21Z  2016-04-14T03:05:03Z         master
# 392   2026-03-14T01:16:58Z  2026-03-11T12:35:38Z           main
# 2879  2026-03-13T23:32:11Z  2026-03-14T02:23:17Z         master
#
#              Owner Login    Owner Type  \
# 2495  rust-in-blockchain  Organization
# 1534              fathyb          User
# 1981               cwalk          User
# 392               liyupi          User
# 2879           OneUptime  Organization
#
#                                       License  \
# 2495                                      NaN
# 1534  BSD 3-Clause "New" or "Revised" License
# 1981                                      NaN
# 392                                       NaN
# 2879                       Apache License 2.0
#
#                                                  Topics
# 2495  awesome, blockchain, consensus, cryptography, ...
# 1534                        browser, chromium, terminal
# 1981  css3, flask, graph, html5, humidity, javascrip...
# 392   ai, algorithm, artificial-intelligence, chatgp...
# 2879  devops, incident-management, incident-response...

# %%
# Dataset info: columns, types, non-null counts
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Domain             3000 non-null   str
#  1   Repository Name    3000 non-null   str
#  2   Full Name          3000 non-null   str
#  3   Description        2994 non-null   str
#  4   Primary Language   2746 non-null   str
#  5   Stars Count        3000 non-null   int64
#  6   Forks Count        3000 non-null   int64
#  7   Watchers Count     3000 non-null   int64
#  8   Open Issues Count  3000 non-null   int64
#  9   Has Wiki           3000 non-null   bool
#  10  Has Pages          3000 non-null   bool
#  11  Has Projects       3000 non-null   bool
#  12  Size (KB)          3000 non-null   int64
#  13  Created At         3000 non-null   str
#  14  Updated At         3000 non-null   str
#  15  Pushed At          3000 non-null   str
#  16  Default Branch     3000 non-null   str
#  17  Owner Login        3000 non-null   str
#  18  Owner Type         3000 non-null   str
#  19  License            2691 non-null   str
#  20  Topics             2793 non-null   str
# dtypes: bool(3), int64(5), str(13)
# memory usage: 430.8 KB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#          Stars Count   Forks Count  Watchers Count  Open Issues Count  \
# count    3000.000000   3000.000000     3000.000000        3000.000000
# mean    20783.222667   3325.095667    20783.222667         398.147000
# std     25860.464547   5538.962493    25860.464547        1065.464885
# min       109.000000      4.000000      109.000000           0.000000
# 25%      6359.250000    677.000000     6359.250000          20.000000
# 50%     14231.000000   1755.000000    14231.000000         109.500000
# 75%     25784.000000   3754.000000    25784.000000         381.250000
# max    409518.000000  75247.000000   409518.000000       18055.000000
#
#           Size (KB)
# count  3.000000e+03
# mean   2.959861e+05
# std    1.684439e+06
# min    2.000000e+00
# 25%    7.420750e+03
# 50%    3.832000e+04
# 75%    1.598460e+05
# max    6.183846e+07

# %%
 # summary for string/categorical columns
df.describe(include='object')
# Out:
# C:\Users\Usman\AppData\Local\Temp\ipykernel_8292\621102087.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#                   Domain Repository Name         Full Name  \
# count               3000            3000              3000
# unique                15            2526              2562
# top     Machine Learning             cli  keras-team/keras
# freq                 200               7                 4
#
#                      Description Primary Language            Created At  \
# count                       2994             2746                  3000
# unique                      2554               54                  2562
# top     Deep Learning for humans           Python  2015-03-28T00:35:42Z
# freq                           4              605                     4
#
#                   Updated At             Pushed At Default Branch Owner Login  \
# count                   3000                  3000           3000        3000
# unique                  2511                  2556             69        2185
# top     2026-03-14T00:42:14Z  2026-03-13T23:34:27Z         master   microsoft
# freq                       8                     4           1586          41
#
#           Owner Type      License         Topics
# count           3000         2691           2793
# unique             2           21           2353
# top     Organization  MIT License  android, java
# freq            1885          898              6

# %%
print("Shape:", df.shape)
# Out:
# Shape: (3000, 21)

# %% [markdown]
# # 4. Data Cleaning

# %%
# Count missing values per column
df.isnull().sum()
# Out:
# Domain                 0
# Repository Name        0
# Full Name              0
# Description            6
# Primary Language     254
# Stars Count            0
# Forks Count            0
# Watchers Count         0
# Open Issues Count      0
# Has Wiki               0
# Has Pages              0
# Has Projects           0
# Size (KB)              0
# Created At             0
# Updated At             0
# Pushed At              0
# Default Branch         0
# Owner Login            0
# Owner Type             0
# License              309
# Topics               207
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# # 5️ Domain Analysis

# %%
# Number of Repositories per Domain
domain_counts = df['Domain'].value_counts()
print(domain_counts)
# Out:
# Domain
# Go                  183
# Rust                178
# Android             176
# iOS                 175
# DevOps              163
# C++                 160
# Deep Learning       159
# Blockchain          157
# Machine Learning    155
# Data Science        150
# Java                148
# Python              147
# Cybersecurity       136
# Web Development     131
# JavaScript          124
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=domain_counts.index, y=domain_counts.values, color="green")
plt.xticks(rotation=45)
plt.title("Number of Repositories per Domain")
plt.ylabel("Repository Count")
plt.show()

# %%
# Most Popular Domain by Stars
domain_stars = df.groupby('Domain')['Stars Count'].sum().sort_values(ascending=False)
print(domain_stars)
# Out:
# Domain
# Python              8981365
# Go                  6107143
# Rust                4644729
# Machine Learning    4446139
# C++                 4429451
# Deep Learning       4104136
# Android             3954991
# JavaScript          3014478
# iOS                 2792170
# Java                2672168
# Data Science        1848496
# DevOps              1520499
# Blockchain           978332
# Cybersecurity        679289
# Web Development      304078
# Name: Stars Count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=domain_stars.index, y=domain_stars.values, color="orange")
plt.xticks(rotation=45)
plt.title("Total Stars per Domain")
plt.ylabel("Total Stars")
plt.show()

# %% [markdown]
# # 6️ Repository Popularity Analysis

# %%
# Top 10 Repositories by Stars
top_starred = df[['Full Name','Stars Count','Domain','Primary Language']].sort_values(by='Stars Count', ascending=False).head(10)
top_starred
# Out:
#                                    Full Name  Stars Count            Domain  \
# 400                  public-apis/public-apis       409518            Python
# 401   EbookFoundation/free-programming-books       383962            Python
# 402         donnemartin/system-design-primer       338749            Python
# 403                     vinta/awesome-python       286998            Python
# 404                     TheAlgorithms/Python       218590            Python
# 0                      tensorflow/tensorflow       194126  Machine Learning
# 200                    tensorflow/tensorflow       194126     Deep Learning
# 1000                   tensorflow/tensorflow       194126               C++
# 2200                         flutter/flutter       175549               iOS
# 2000                         flutter/flutter       175549           Android
#
#      Primary Language
# 400            Python
# 401            Python
# 402            Python
# 403            Python
# 404            Python
# 0                 C++
# 200               C++
# 1000              C++
# 2200             Dart
# 2000             Dart

# %%
# Top 10 Repositories by Forks
top_forks = df[['Full Name','Forks Count','Domain','Primary Language']].sort_values(by='Forks Count', ascending=False).head(10)
top_forks
# Out:
#                                    Full Name  Forks Count            Domain  \
# 0                      tensorflow/tensorflow        75247  Machine Learning
# 200                    tensorflow/tensorflow        75246     Deep Learning
# 1000                   tensorflow/tensorflow        75246               C++
# 401   EbookFoundation/free-programming-books        66010            Python
# 205                            opencv/opencv        56553     Deep Learning
# 1007                           opencv/opencv        56553               C++
# 402         donnemartin/system-design-primer        54874            Python
# 404                     TheAlgorithms/Python        50173            Python
# 400                  public-apis/public-apis        44245            Python
# 1203                   kubernetes/kubernetes        42674                Go
#
#      Primary Language
# 0                 C++
# 200               C++
# 1000              C++
# 401            Python
# 205               C++
# 1007              C++
# 402            Python
# 404            Python
# 400            Python
# 1203               Go

# %%
# Correlation Between Engagement Metrics
numeric_cols = ['Stars Count','Forks Count','Watchers Count','Open Issues Count','Size (KB)']
corr = df[numeric_cols].corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Numeric Metrics")
plt.show()

# %% [markdown]
# # 7️ Programming Language Analysis

# %%
# Top 10 primary languages used
top_languages = df['Primary Language'].value_counts().head(10)
print(top_languages)
# Out:
# Primary Language
# Python              530
# Go                  327
# C++                 250
# Rust                242
# Java                228
# JavaScript          218
# TypeScript          121
# Jupyter Notebook     95
# Swift                54
# HTML                 40
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=top_languages.index, y=top_languages.values, color="teal")
plt.xticks(rotation=45)
plt.title("Top 10 Primary Languages in Top GitHub Repositories")
plt.ylabel("Repository Count")
plt.show()

# %% [markdown]
# # 8️ Owner Type Analysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Owner Type', data=df, color="skyblue")  # single color
plt.title("Repository Ownership: User vs Organization")
plt.show()

# %% [markdown]
# # 9️ Time-Based Analysis

# %%
# Convert date columns to datetime
df['Created At'] = pd.to_datetime(df['Created At'])
df['Updated At'] = pd.to_datetime(df['Updated At'])
df['Pushed At'] = pd.to_datetime(df['Pushed At'])

# Repositories created per year
df['Created Year'] = df['Created At'].dt.year
created_year_counts = df['Created Year'].value_counts().sort_index()

plt.figure(figsize=(12,6))
sns.lineplot(x=created_year_counts.index, y=created_year_counts.values, marker="o")
plt.title("Repositories Created Per Year")
plt.ylabel("Count")
plt.show()

# %%
# Topics & Description Analysis
from collections import Counter

all_topics = df['Topics'].dropna().apply(lambda x: x.split(','))
flat_topics = [topic.strip() for sublist in all_topics for topic in sublist]
top_topics = Counter(flat_topics).most_common(20)

# Display
pd.DataFrame(top_topics, columns=['Topic','Count'])
# Out:
#                Topic  Count
# 0             python    405
# 1   machine-learning    402
# 2      deep-learning    349
# 3            android    336
# 4                ios    258
# 5      hacktoberfest    250
# 6       data-science    224
# 7             devops    185
# 8               rust    181
# 9         blockchain    170
# 10        javascript    169
# 11            golang    162
# 12                go    155
# 13           pytorch    153
# 14     cybersecurity    146
# 15                ai    142
# 16   web-development    134
# 17              java    133
# 18        kubernetes    117
# 19             linux    116

# %%
# Save with new computed columns
df.to_csv("github_top_repositories_cleaned.csv", index=False)

# %% [markdown]
# ##  Conclusion
#
# This analysis shows that successful GitHub repositories are driven by:
# - Strong community engagement
# - Popular programming ecosystems
# - High usability and real-world value
#
# ---
#
# 🚀 Success on GitHub is not just about code —
# it’s about **impact, usability, and community**.
#
# ---
#
# ⭐ If you like this notebook, please upvote!
